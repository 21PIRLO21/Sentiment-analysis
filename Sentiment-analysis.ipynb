# %%
text0 = "I am happy today.I feel sad today."
text1 = "I am happy today. I feel sad today."
# text0和text1的区别在于，第一个句号之火text1后面有一个空格，二text0没有,这会造成后面textblob分词分句是巨大的差异。

# %%
from textblob import TextBlob
blob0 = TextBlob(text0)
blob1 = TextBlob(text1)

blob0, blob1
# Out:
# (TextBlob("I am happy today.I feel sad today."),
#  TextBlob("I am happy today. I feel sad today."))

# %%
blob.sentences
# 这是在没有将 punkt 配置好之前的报错，按照这个提示没能安装成功 punkt ，原因是相关的压缩包根本下载不下来。最终通过其他渠道下载了下来。
# Out:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   Searched in:
#     - 'C:\\Users\\21PIRLO/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'D:\\anaconda\\nltk_data'
#     - 'D:\\anaconda\\share\\nltk_data'
#     - 'D:\\anaconda\\lib\\nltk_data'
#     - 'C:\\Users\\21PIRLO\\AppData\\Roaming\\nltk_data'
#     - u''
# **********************************************************************
# ---------------------------------------------------------------------------
# MissingCorpusError                        Traceback (most recent call last)
# <ipython-input-6-9f557a43ac6b> in <module>()
# ----> 1 blob.sentences
#
# D:\anaconda\lib\site-packages\textblob\decorators.pyc in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# D:\anaconda\lib\site-packages\textblob\blob.pyc in sentences(self)
#     637     def sentences(self):
#     638         """Return list of :class:`Sentence <Sentence>` objects."""
# --> 639         return self._create_sentence_objects()
#     640
#     641     @cached_property
#
# D:\anaconda\lib\site-packages\textblob\blob.pyc in _create_sentence_objects(self)
#     681         '''
#     682         sentence_objects = []
# --> 683         sentences = sent_tokenize(self.raw)
#     684         char_index = 0  # Keeps track of character index within the blob
#     685         for sent in sentences:
#
# D:\anaconda\lib\site-packages\textblob\base.pyc in itokenize(self, text, *args, **kwargs)
#      62         :rtype: generator
#      63         """
# ---> 64         return (t for t in self.tokenize(text, *args, **kwargs))
#      65
#      66 ##### SENTIMENT ANALYZERS ####
#
# D:\anaconda\lib\site-packages\textblob\decorators.pyc in decorated(*args, **kwargs)
#      36         except LookupError as err:
#      37             print(err)
# ---> 38             raise MissingCorpusError()
#      39     return decorated
#
# MissingCorpusError:
# Looks like you are missing some required data for this feature.
#
# To download the necessary data, simply run
#
#     python -m textblob.download_corpora
#
# or use the NLTK downloader to download the missing data: http://nltk.org/data.html
# If this doesn't fix the problem, file an issue at https://github.com/sloria/TextBlob/issues.

# %%
import nltk
nltk.download('punkt')
# 按照提示下载 punkt ，之后一直就卡在了下面这个状态
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\21PIRLO\AppData\Roaming\nltk_data...

# %%
blob.sentences
# 一个不知道愿意的错误，可能是自己下往 nltk 目录下装文件造成的。
# Out:
# ---------------------------------------------------------------------------
# BadZipfile                                Traceback (most recent call last)
# <ipython-input-3-9f557a43ac6b> in <module>()
# ----> 1 blob.sentences
#
# D:\anaconda\lib\site-packages\textblob\decorators.pyc in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# D:\anaconda\lib\site-packages\textblob\blob.pyc in sentences(self)
#     637     def sentences(self):
#     638         """Return list of :class:`Sentence <Sentence>` objects."""
# --> 639         return self._create_sentence_objects()
#     640
#     641     @cached_property
#
# D:\anaconda\lib\site-packages\textblob\blob.pyc in _create_sentence_objects(self)
#     681         '''
#     682         sentence_objects = []
# --> 683         sentences = sent_tokenize(self.raw)
#     684         char_index = 0  # Keeps track of character index within the blob
#     685         for sent in sentences:
#
# D:\anaconda\lib\site-packages\textblob\base.pyc in itokenize(self, text, *args, **kwargs)
#      62         :rtype: generator
#      63         """
# ---> 64         return (t for t in self.tokenize(text, *args, **kwargs))
#      65
#      66 ##### SENTIMENT ANALYZERS ####
#
# D:\anaconda\lib\site-packages\textblob\decorators.pyc in decorated(*args, **kwargs)
#      33     def decorated(*args, **kwargs):
#      34         try:
# ---> 35             return func(*args, **kwargs)
#      36         except LookupError as err:
#      37             print(err)
#
# D:\anaconda\lib\site-packages\textblob\tokenizers.pyc in tokenize(self, text)
#      55     def tokenize(self, text):
#      56         '''Return a list of sentences.'''
# ---> 57         return nltk.tokenize.sent_tokenize(text)
#      58
#      59
#
# D:\anaconda\lib\site-packages\nltk\tokenize\__init__.pyc in sent_tokenize(text, language)
#      92     :param language: the model name in the Punkt corpus
#      93     """
# ---> 94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
#      95     return tokenizer.tokenize(text)
#      96
#
# D:\anaconda\lib\site-packages\nltk\data.pyc in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     834
#     835     # Load the resource.
# --> 836     opened_resource = _open(resource_url)
#     837
#     838     if format == 'raw':
#
# D:\anaconda\lib\site-packages\nltk\data.pyc in _open(resource_url)
#     952
#     953     if protocol is None or protocol.lower() == 'nltk':
# --> 954         return find(path_, path + ['']).open()
#     955     elif protocol.lower() == 'file':
#     956         # urllib might not use mode='rb', so handle this one ourselves:
#
# D:\anaconda\lib\site-packages\nltk\data.pyc in find(resource_name, paths)
#     653                                      [pieces[i] + '.zip'] + pieces[i:])
#     654             try:
# --> 655                 return find(modified_name, paths)
#     656             except LookupError:
#     657                 pass
#
# D:\anaconda\lib\site-packages\nltk\data.pyc in find(resource_name, paths)
#     639                 if os.path.exists(p):
#     640                     try:
# --> 641                         return ZipFilePathPointer(p, zipentry)
#     642                     except IOError:
#     643                         # resource not in zipfile
#
# D:\anaconda\lib\site-packages\nltk\compat.pyc in _decorator(*args, **kwargs)
#     219     def _decorator(*args, **kwargs):
#     220         args = (args[0], add_py3_data(args[1])) + args[2:]
# --> 221         return init_func(*args, **kwargs)
#     222     return wraps(init_func)(_decorator)
#     223
#
# D:\anaconda\lib\site-packages\nltk\data.pyc in __init__(self, zipfile, entry)
#     486         """
#     487         if isinstance(zipfile, string_types):
# --> 488             zipfile = OpenOnDemandZipFile(os.path.abspath(zipfile))
#     489
#     490         # Normalize the entry string, it should be relative:
#
# D:\anaconda\lib\site-packages\nltk\compat.pyc in _decorator(*args, **kwargs)
#     219     def _decorator(*args, **kwargs):
#     220         args = (args[0], add_py3_data(args[1])) + args[2:]
# --> 221         return init_func(*args, **kwargs)
#     222     return wraps(init_func)(_decorator)
#     223
#
# D:\anaconda\lib\site-packages\nltk\data.pyc in __init__(self, filename)
#    1012         if not isinstance(filename, string_types):
#    1013             raise TypeError('ReopenableZipFile filename must be a string')
# -> 1014         zipfile.ZipFile.__init__(self, filename)
#    1015         assert self.filename == filename
#    1016         self.close()
#
# D:\anaconda\lib\zipfile.pyc in __init__(self, file, mode, compression, allowZip64)
#     768         try:
#     769             if key == 'r':
# --> 770                 self._RealGetContents()
#     771             elif key == 'w':
#     772                 # set the modified flag so central directory gets written
#
# D:\anaconda\lib\zipfile.pyc in _RealGetContents(self)
#     809             raise BadZipfile("File is not a zip file")
#     810         if not endrec:
# --> 811             raise BadZipfile, "File is not a zip file"
#     812         if self.debug > 1:
#     813             print endrec
#
# BadZipfile: File is not a zip file

# %%
blob0.sentences
# Out:
# [Sentence("I am happy today.I feel sad today.")]

# %%
blob1.sentences
# 注意与上面 blob0 输出的不同，这里列表会有两个句子，这才是我们想要的结果。
# Out:
# [Sentence("I am happy today."), Sentence("I feel sad today.")]

# %%
blob0.sentences[0].sentiment
# Out:
# Sentiment(polarity=0.15000000000000002, subjectivity=1.0)

# %%
blob0.sentences[1].sentiment
# 因为blob0 列表里只有一个元素，所以blob0.sentences[1]会报错。
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-f28ec8142f62> in <module>()
# ----> 1 blob.sentences[1].sentiment
#
# IndexError: list index out of range

# %%
blob1.sentences[0].sentiment
# Out:
# Sentiment(polarity=0.8, subjectivity=1.0)

# %%
blob1.sentences[1].sentiment
# Out:
# Sentiment(polarity=-0.5, subjectivity=1.0)
